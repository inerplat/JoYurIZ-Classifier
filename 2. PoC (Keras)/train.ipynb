# %%
import numpy as np
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping
np.random.seed(5)

# %%
trainDataGen = ImageDataGenerator(rescale=1./255,
                                 zoom_range=0.2,
                                 width_shift_range=0.1,
                                 height_shift_range=0.1,
                                 horizontal_flip=True,
                                 validation_split=0.25)
trainGenerator = trainDataGen.flow_from_directory( './trainImage',         
                                                  target_size=(128, 128),         
                                                  batch_size=100,         
                                                  class_mode='categorical',
                                                 subset='training') 
testGenerator = trainDataGen.flow_from_directory( './trainImage',         
                                                target_size=(128, 128),             
                                                batch_size=100,         
                                                class_mode='categorical',
                                                subset='validation')
# Out:
# Found 478 images belonging to 3 classes.
# Found 158 images belonging to 3 classes.

# %%
model = Sequential() 

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(128,128,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu')) 
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 

model.add(Conv2D(256, (3, 3), activation='relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(Conv2D(512, (3, 3), activation='relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 

model.add(Flatten()) 
model.add(Dense(1024, activation='relu')) 
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
checkpoint = ModelCheckpoint(filepath="./model2.h5", monitor="val_loss", verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor="val_loss", patience=15)

# %%
history = model.fit_generator(trainGenerator,         
                    steps_per_epoch=30,         
                    epochs=200,         
                    validation_data=testGenerator,         
                    validation_steps=30,
                   callbacks =[checkpoint, early_stopping])
# Out:
# Epoch 1/200
# 30/30 [==============================] - 96s 3s/step - loss: 1.0741 - acc: 0.4168 - val_loss: 1.0450 - val_acc: 0.4177
#
# Epoch 00001: val_loss improved from inf to 1.04504, saving model to ./model2.h5
# Epoch 2/200
# 30/30 [==============================] - 92s 3s/step - loss: 1.0413 - acc: 0.4124 - val_loss: 0.9883 - val_acc: 0.5667
#
# Epoch 00002: val_loss improved from 1.04504 to 0.98827, saving model to ./model2.h5
# Epoch 3/200
# 30/30 [==============================] - 92s 3s/step - loss: 0.9679 - acc: 0.5323 - val_loss: 0.8639 - val_acc: 0.5582
#
# Epoch 00003: val_loss improved from 0.98827 to 0.86390, saving model to ./model2.h5
# Epoch 4/200
# 30/30 [==============================] - 92s 3s/step - loss: 0.7998 - acc: 0.6325 - val_loss: 0.7575 - val_acc: 0.6511
#
# Epoch 00004: val_loss improved from 0.86390 to 0.75751, saving model to ./model2.h5
# Epoch 5/200
# 30/30 [==============================] - 93s 3s/step - loss: 0.6844 - acc: 0.6851 - val_loss: 0.6962 - val_acc: 0.7477
#
# Epoch 00005: val_loss improved from 0.75751 to 0.69621, saving model to ./model2.h5
# Epoch 6/200
# 30/30 [==============================] - 92s 3s/step - loss: 0.5762 - acc: 0.7502 - val_loss: 0.6904 - val_acc: 0.7346
#
# Epoch 00006: val_loss improved from 0.69621 to 0.69040, saving model to ./model2.h5
# Epoch 7/200
# 30/30 [==============================] - 93s 3s/step - loss: 0.5094 - acc: 0.7856 - val_loss: 0.6523 - val_acc: 0.7456
#
# Epoch 00007: val_loss improved from 0.69040 to 0.65231, saving model to ./model2.h5
# Epoch 8/200
# 30/30 [==============================] - 97s 3s/step - loss: 0.5177 - acc: 0.7789 - val_loss: 0.6634 - val_acc: 0.7722
#
# Epoch 00008: val_loss did not improve from 0.65231
# Epoch 9/200
# 30/30 [==============================] - 88s 3s/step - loss: 0.4365 - acc: 0.8200 - val_loss: 0.7203 - val_acc: 0.7776
#
# Epoch 00009: val_loss did not improve from 0.65231
# Epoch 10/200
# 30/30 [==============================] - 92s 3s/step - loss: 0.3799 - acc: 0.8440 - val_loss: 0.5537 - val_acc: 0.7899
#
# Epoch 00010: val_loss improved from 0.65231 to 0.55374, saving model to ./model2.h5
# Epoch 11/200
# 30/30 [==============================] - 92s 3s/step - loss: 0.3353 - acc: 0.8638 - val_loss: 0.6086 - val_acc: 0.7608
#
# Epoch 00011: val_loss did not improve from 0.55374
# Epoch 12/200
# 30/30 [==============================] - 93s 3s/step - loss: 0.3211 - acc: 0.8725 - val_loss: 0.6462 - val_acc: 0.7667
#
# Epoch 00012: val_loss did not improve from 0.55374
# Epoch 13/200
# 30/30 [==============================] - 87s 3s/step - loss: 0.3447 - acc: 0.8561 - val_loss: 0.6254 - val_acc: 0.7726
#
# Epoch 00013: val_loss did not improve from 0.55374
# Epoch 14/200
# 30/30 [==============================] - 85s 3s/step - loss: 0.2934 - acc: 0.8888 - val_loss: 0.5498 - val_acc: 0.8190
#
# Epoch 00014: val_loss improved from 0.55374 to 0.54981, saving model to ./model2.h5
# Epoch 15/200
# 30/30 [==============================] - 85s 3s/step - loss: 0.2388 - acc: 0.9103 - val_loss: 0.5894 - val_acc: 0.8477
#
# Epoch 00015: val_loss did not improve from 0.54981
# Epoch 16/200
# 30/30 [==============================] - 92s 3s/step - loss: 0.1858 - acc: 0.9288 - val_loss: 0.6565 - val_acc: 0.8122
#
# Epoch 00016: val_loss did not improve from 0.54981
# Epoch 17/200
# 30/30 [==============================] - 96s 3s/step - loss: 0.1914 - acc: 0.9274 - val_loss: 0.6495 - val_acc: 0.8350
#
# Epoch 00017: val_loss did not improve from 0.54981
# Epoch 18/200
# 30/30 [==============================] - 94s 3s/step - loss: 0.1650 - acc: 0.9361 - val_loss: 0.5607 - val_acc: 0.8405
#
# Epoch 00018: val_loss did not improve from 0.54981
# Epoch 19/200
# 30/30 [==============================] - 94s 3s/step - loss: 0.1694 - acc: 0.9336 - val_loss: 0.4217 - val_acc: 0.8624
#
# Epoch 00019: val_loss improved from 0.54981 to 0.42169, saving model to ./model2.h5
# Epoch 20/200
# 30/30 [==============================] - 97s 3s/step - loss: 0.2035 - acc: 0.9186 - val_loss: 0.5842 - val_acc: 0.8451
#
# Epoch 00020: val_loss did not improve from 0.42169
# Epoch 21/200
# 30/30 [==============================] - 87s 3s/step - loss: 0.1447 - acc: 0.9459 - val_loss: 0.6000 - val_acc: 0.8350
#
# Epoch 00021: val_loss did not improve from 0.42169
# Epoch 22/200
# 30/30 [==============================] - 93s 3s/step - loss: 0.1051 - acc: 0.9605 - val_loss: 0.7209 - val_acc: 0.8511
#
# Epoch 00022: val_loss did not improve from 0.42169
# Epoch 23/200
# 30/30 [==============================] - 93s 3s/step - loss: 0.0744 - acc: 0.9707 - val_loss: 0.6123 - val_acc: 0.8477
#
# Epoch 00023: val_loss did not improve from 0.42169
# Epoch 24/200
# 30/30 [==============================] - 93s 3s/step - loss: 0.0888 - acc: 0.9599 - val_loss: 0.7144 - val_acc: 0.8574
#
# Epoch 00024: val_loss did not improve from 0.42169
# Epoch 25/200
# 30/30 [==============================] - 93s 3s/step - loss: 0.1598 - acc: 0.9445 - val_loss: 0.7725 - val_acc: 0.8173
#
# Epoch 00025: val_loss did not improve from 0.42169
# Epoch 26/200
# 30/30 [==============================] - 93s 3s/step - loss: 0.1653 - acc: 0.9356 - val_loss: 0.5390 - val_acc: 0.8637
#
# Epoch 00026: val_loss did not improve from 0.42169
# Epoch 27/200
# 30/30 [==============================] - 93s 3s/step - loss: 0.1125 - acc: 0.9579 - val_loss: 0.7089 - val_acc: 0.8468
#
# Epoch 00027: val_loss did not improve from 0.42169
# Epoch 28/200
# 30/30 [==============================] - 91s 3s/step - loss: 0.0781 - acc: 0.9711 - val_loss: 0.8086 - val_acc: 0.8570
#
# Epoch 00028: val_loss did not improve from 0.42169
# Epoch 29/200
# 30/30 [==============================] - 86s 3s/step - loss: 0.0640 - acc: 0.9728 - val_loss: 0.7447 - val_acc: 0.8460
#
# Epoch 00029: val_loss did not improve from 0.42169
# Epoch 30/200
# 30/30 [==============================] - 86s 3s/step - loss: 0.0821 - acc: 0.9688 - val_loss: 0.8069 - val_acc: 0.8447
#
# Epoch 00030: val_loss did not improve from 0.42169
# Epoch 31/200
# 30/30 [==============================] - 86s 3s/step - loss: 0.0658 - acc: 0.9764 - val_loss: 0.7105 - val_acc: 0.8658
#
# Epoch 00031: val_loss did not improve from 0.42169
# Epoch 32/200
# 30/30 [==============================] - 86s 3s/step - loss: 0.1452 - acc: 0.9472 - val_loss: 0.8057 - val_acc: 0.8262
#
# Epoch 00032: val_loss did not improve from 0.42169
# Epoch 33/200
# 30/30 [==============================] - 86s 3s/step - loss: 0.0874 - acc: 0.9646 - val_loss: 0.6718 - val_acc: 0.8658
#
# Epoch 00033: val_loss did not improve from 0.42169
# Epoch 34/200
# 30/30 [==============================] - 86s 3s/step - loss: 0.0575 - acc: 0.9801 - val_loss: 0.8081 - val_acc: 0.8532
#
# Epoch 00034: val_loss did not improve from 0.42169
